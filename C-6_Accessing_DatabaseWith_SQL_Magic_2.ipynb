# %%
# %load_ext sql
# Out:
# The sql extension is already loaded. To reload it, use:
#   %reload_ext sql

# %%
# %sql ibm_db_sa://dvx78774:j0mTJKkaFz2VplvP@815fa4db-dc03-4c70-869a-a9cc13f33084.bs2io90l08kqb1od8lcg.databases.appdomain.cloud:30367/BLUDB?security=SSL

# %%
# %sql select * from INTERNATIONAL_STUDENT_TEST_SCORES
# Out:
#  * ibm_db_sa://dvx78774:***@815fa4db-dc03-4c70-869a-a9cc13f33084.bs2io90l08kqb1od8lcg.databases.appdomain.cloud:30367/BLUDB
# Done.
# [('United States', 'Marshall', 'Bernadot', 54),
#  ('Ghana', 'Celinda', 'Malkin', 51),
#  ('Ukraine', 'Guillermo', 'Furze', 53),
#  ('Greece', 'Aharon', 'Tunnow', 48),
#  ('Russia', 'Bail', 'Goodwin', 46),
#  ('Poland', 'Cole', 'Winteringham', 49),
#  ('Sweden', 'Emlyn', 'Erricker', 55),
#  ('Russia', 'Cathee', 'Sivewright', 49),
#  ('China', 'Barny', 'Ingerson', 57),
#  ('Uganda', 'Sharla', 'Papaccio', 55),
#  ('China', 'Stella', 'Youens', 51),
#  ('Poland', 'Julio', 'Buesden', 48),
#  ('United States', 'Tiffie', 'Cosely', 58),
#  ('Poland', 'Auroora', 'Stiffell', 45),
#  ('China', 'Clarita', 'Huet', 52),
#  ('Poland', 'Shannon', 'Goulden', 45),
#  ('Philippines', 'Emylee', 'Privost', 50),
#  ('France', 'Madelina', 'Burk', 49),
#  ('China', 'Saunderson', 'Root', 58),
#  ('Indonesia', 'Bo', 'Waring', 55),
#  ('China', 'Hollis', 'Domotor', 45),
# ...

# %%
country='China'
# %sql select * from INTERNATIONAL_STUDENT_TEST_SCORES where country=:country
# Out:
#  * ibm_db_sa://dvx78774:***@815fa4db-dc03-4c70-869a-a9cc13f33084.bs2io90l08kqb1od8lcg.databases.appdomain.cloud:30367/BLUDB
# Done.
# [('China', 'Barny', 'Ingerson', 57),
#  ('China', 'Stella', 'Youens', 51),
#  ('China', 'Clarita', 'Huet', 52),
#  ('China', 'Saunderson', 'Root', 58),
#  ('China', 'Hollis', 'Domotor', 45),
#  ('China', 'Cristabel', 'Radeliffe', 48),
#  ('China', 'Wallis', 'Bartleet', 58),
#  ('China', 'Sallyann', 'Exley', 51),
#  ('China', 'Deanne', 'Edwinson', 45),
#  ('China', 'Georgiana', 'Epple', 51),
#  ('China', 'Lianna', 'Gatward', 43),
#  ('China', 'Alvira', 'Tamas', 50),
#  ('China', 'Cash', 'Landis', 48),
#  ('China', 'Ulberto', 'Riggeard', 48),
#  ('China', 'Conroy', 'Egdal', 48),
#  ('China', 'Aidan', 'Rudeyeard', 50),
#  ('China', 'Gisele', 'Enns', 52),
#  ('China', 'Etan', 'Burn', 53),
#  ('China', 'Ossie', 'Woodley', 52),
#  ('China', 'Mart', 'Coling', 52),
#  ('China', 'Berni', 'Daintier', 55),
#  ('China', 'Paulo', 'Seivertsen', 47),
# ...

# %%
import pandas

# %%
v1=%sql select test_score,country from INTERNATIONAL_STUDENT_TEST_SCORES ORDER BY test_score desc
# Out:
#  * ibm_db_sa://dvx78774:***@815fa4db-dc03-4c70-869a-a9cc13f33084.bs2io90l08kqb1od8lcg.databases.appdomain.cloud:30367/BLUDB
# Done.

# %%
v1
# Out:
# [(60, 'Venezuela'),
#  (58, 'United States'),
#  (58, 'China'),
#  (58, 'China'),
#  (58, 'Ireland'),
#  (57, 'China'),
#  (57, 'Philippines'),
#  (56, 'Portugal'),
#  (55, 'Sweden'),
#  (55, 'Uganda'),
#  (55, 'Indonesia'),
#  (55, 'China'),
#  (54, 'United States'),
#  (54, 'France'),
#  (54, 'Ukraine'),
#  (54, 'Canada'),
#  (54, 'Niger'),
#  (53, 'Ukraine'),
#  (53, 'Norway'),
#  (53, 'Latvia'),
#  (53, 'Sweden'),
#  (53, 'France'),
#  (53, 'China'),
#  (53, 'Vietnam'),
#  (53, 'Australia'),
#  (52, 'China'),
#  (52, 'Philippines'),
#  (52, 'Czech Republic'),
#  (52, 'China'),
#  (52, 'China'),
#  (52, 'Ukraine'),
#  (52, 'China'),
#  (52, 'China'),
#  (51, 'Ghana'),
#  (51, 'China'),
#  (51, 'China'),
#  (51, 'Armenia'),
#  (51, 'China'),
#  (51, 'Philippines'),
#  (51, 'France'),
#  (51, 'Russia'),
#  (50, 'Philippines'),
#  (50, 'Azerbaijan'),
#  (50, 'Poland'),
#  (50, 'Papua New Guinea'),
#  (50, 'China'),
#  (50, 'Latvia'),
#  (50, 'Poland'),
#  (50, 'China'),
# ...

# %%
dataframe=pandas.DataFrame(v1)

# %%
dataframe
# Out:
#      0              1
# 0   60      Venezuela
# 1   58  United States
# 2   58          China
# 3   58          China
# 4   58        Ireland
# ..  ..            ...
# 94  43          China
# 95  43        Jamaica
# 96  40         Russia
# 97  38        Moldova
# 98  38         Russia
#
# [99 rows x 2 columns]

# %%
import seaborn

plot=seaborn.barplot(x=1,y=0,data=dataframe)
